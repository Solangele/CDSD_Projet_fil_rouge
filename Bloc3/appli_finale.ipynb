# %%
import os
import psycopg2
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import seaborn as sns

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Connexion PostgreSQL Gold et Récupération des données

# %%
load_dotenv(dotenv_path="../../.env")

conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="datapulse_db",
    user=os.getenv("POSTGRES_USER"),
    password=os.getenv("POSTGRES_PASSWORD")
)

query = """
SELECT t.filename, t.minio_path, i.label_name as instrument
FROM audio_tracks t
JOIN instruments i ON t.instrument_id = i.id;
"""
df_gold = pd.read_sql(query, conn)
conn.close()
# Out:
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_8472\3738065340.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold = pd.read_sql(query, conn)

# %%
def adapt_local_path(minio_path):
    """ 
    Résout et reconstruit le chemin d'accès physique local d'un fichier audio à partir de son identifiant de stockage distant (MinIO)

    Cette fonction utilitaire permet à la couche de modélisation (Orchestrateur Python) de localiser et charger en mémoire les signaux audio bruts. 
    Elle applique une règle de routage des dossiers selon l'origine du jeu de données (Philharmonia vs IRMAS)

    Argument : 
        minio_path (str) : le chemin logique de l'URI du fichier stocké dans le Data Lake de la couche Bronze (ex : "philharmonia/23.wav)
    
    Retourne :
        str : Le chemin d'accès système relatif vers le fichier local (ex : "../data/scrap/..."). 
    """
    if "philharmonia" in minio_path:
        return os.path.join("../data/scrap", minio_path)
    else:
        return os.path.join("../data", minio_path)

df_gold['chemin_local'] = df_gold['minio_path'].apply(adapt_local_path)
print(f"{len(df_gold)} pistes prêtes à être analysées via PostgreSQL Gold.")
# Out:
# 23262 pistes prêtes à être analysées via PostgreSQL Gold.

# %%
df_gold['chemin_local'] = df_gold['minio_path'].apply(adapt_local_path)

df_gold_clean = df_gold[
    df_gold['instrument'].notna() & 
    (df_gold['instrument'].str.lower() != 'unknown')
].reset_index(drop= True)

print(f"Pistes initiales dans PostgreSQL Gold : {len(df_gold)}")
print(f"Pistes nettoyées et viables pour l'IA : {len(df_gold_clean)} (727 'unknown' et 2 manquants supprimés).")
# Out:
# Pistes initiales dans PostgreSQL Gold : 23262
# Pistes nettoyées et viables pour l'IA : 22535 (727 'unknown' et 2 manquants supprimés).

# %%
def extract_boosted_features(chemin_fichier):
    """ 
    Analyse le signal audio brut pour extraire un vecteur combiné de caractéristiques acoustiques avancées (Timbre, Brillance, Harmonie).

    Cette fonction charge le signal à une fréqence native de 22050 Hz, extrait trois descripteurs complémentaires avec librosa, puis calculs leur moyenne temporelle pour obtenir une signature numérique de taille fixe (39 features).
    Elle intègre une gestion robuste des erreurs pour sécuriser le pipeline.

    Détail du vecteur extrait (39 composants) :
        - 26 coefficients MFCCC : Enveloppe spectrale et timbre de l'instrument.
        - 1 Centroïde Spectral : Brillance globale / "centre de gravité" des fréquences.
        - 12 coefficients Chroma STFT : profil harmonique de la piste (notes de musique).
    
    Arguments :
        - chemin_fichier (str) : chemin d'accès local vers le fichier audio (.wav ou .mp3)

    Retourne : 
        - numpy.array : Vecteur 1D de dimension (39,) regroupant l'ensemble des caractéristiques extraites, ou None en cas d'erreur ou de fichier vide. 
    """
    try:
        y, sr = librosa.load(chemin_fichier, duration=None, sr=22050) 
        if len(y) == 0: 
            return None
        
        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=26).T, axis=0)
        
        centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr).T, axis=0)
        
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr).T, axis=0)
        
        return np.concatenate((mfccs, centroid, chroma))
    except Exception:
        return None

# %% [markdown]
# ## Processing et cartographie des familles de routage métier

# %%
audio_features_list = []
raw_labels_list = []

print("Extraction des caractéristiques acoustiques boostées...")
for idx, row in df_gold_clean.iterrows():
    features = extract_boosted_features(row['chemin_local'])
    if features is not None:
        audio_features_list.append(features)
        raw_labels_list.append(row['instrument'])

X_audio = np.array(audio_features_list)

# Dictionnaire de regroupement analytique en 7 familles cibles
mapping_families = {
    "organ": "orgues_et_claviers", "org": "orgues_et_claviers",
    "piano": "pianos_et_claviers", "celesta": "pianos_et_claviers","pia": "pianos_et_claviers",
    "acoustic_guitar": "cordes_pincees","gac": "cordes_pincees", "gel": "cordes_pincees", "electric_guitar": "cordes_pincees", "guitar": "cordes_pincees", "banjo": "cordes_pincees", "mandolin": "cordes_pincees",
    "cello": "cordes_frottees", "violin": "cordes_frottees", "viola": "cordes_frottees", "double bass": "cordes_frottees", "bassoon": "cordes_frottees", "contrabassoon": "cordes_frottees", "cel": "cordes_frottees", "vio": "cordes_frottees",
    "voice": "voix","voi": "voix",
    "percussion": "percussions",
    "bass clarinet": "vents_et_cuivres", "clarinet": "vents_et_cuivres", "flute": "vents_et_cuivres", "saxophone": "vents_et_cuivres", "trumpet": "vents_et_cuivres", "trombone": "vents_et_cuivres", "cor anglais": "vents_et_cuivres", "oboe": "vents_et_cuivres", "french horn": "vents_et_cuivres", "tuba": "vents_et_cuivres", "cla": "vents_et_cuivres", "flu": "vents_et_cuivres", "sax": "vents_et_cuivres", "tru": "vents_et_cuivres"
}

# Remplacement et mapping de la cible
y_instruments = pd.Series(raw_labels_list).replace(mapping_families).values
print(f"Format de la matrice X : {X_audio.shape}")
print(f"Nombre de Familles Métiers cibles : {len(np.unique(y_instruments))}")
# Out:
# Extraction des caractéristiques acoustiques boostées...
# c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1728
#   warnings.warn(
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_8472\3605999702.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(chemin_fichier, duration=None, sr=22050)
# c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ...

# %% [markdown]
# ## Séparation Train/Test et équilibrage des classes via SMOTE

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_audio, y_instruments, test_size=0.2, random_state=42, stratify=y_instruments
)

print("Application du SMOTE pour rééquilibrer le jeu d'entraînement...")
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(f"Taille du Train initial : {X_train.shape[0]} | Après SMOTE : {X_train_resampled.shape[0]}")
# Out:
# Application du SMOTE pour rééquilibrer le jeu d'entraînement...
# Taille du Train initial : 18026 | Après SMOTE : 55076

# %% [markdown]
# ## Entraînement du Classifieur Random Forest

# %%
print("Entraînement de la Forêt Aléatoire en cours...")
model_application = RandomForestClassifier(
    n_estimators=300,
    max_depth=30,
    min_samples_split=2,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

model_application.fit(X_train_resampled, y_train_resampled)
print("Modèle entraîné et prêt pour l'évaluation !")
# Out:
# Entraînement de la Forêt Aléatoire en cours...
# Modèle entraîné et prêt pour l'évaluation !

# %% [markdown]
# ## Evaluation des performances et cartographie des erreurs

# %%
y_pred = model_application.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"ACCURACY FINALE DU MODÈLE ACOUSTIQUE : {accuracy:.2%}\n")
print("=== RAPPORT DE CLASSIFICATION ===")
print(classification_report(y_test, y_pred))


fig, ax = plt.subplots(figsize=(10, 8))
ConfusionMatrixDisplay.from_predictions(
    y_test, 
    y_pred, 
    ax=ax, 
    cmap='Blues', 
    xticks_rotation=45
)
plt.title("Matrice de Confusion Globale : Reconnaissance des 7 Familles d'Instruments (Features Combinées)", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Familles Prédites", fontsize=12, fontweight='bold', labelpad=15)
plt.ylabel("Familles Réelles (Vérité terrain)", fontsize=12, fontweight='bold', labelpad=15)

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# ACCURACY FINALE DU MODÈLE ACOUSTIQUE : 85.76%
#
# === RAPPORT DE CLASSIFICATION ===
#                     precision    recall  f1-score   support
#
#    cordes_frottees       0.93      0.98      0.96      1129
#     cordes_pincees       0.79      0.75      0.77       605
# orgues_et_claviers       0.62      0.74      0.67       164
#        percussions       1.00      0.77      0.87        30
# pianos_et_claviers       0.66      0.71      0.68       400
#   vents_et_cuivres       0.95      0.88      0.91      1967
#               voix       0.54      0.70      0.61       212
#
#           accuracy                           0.86      4507
#          macro avg       0.78      0.79      0.78      4507
#       weighted avg       0.87      0.86      0.86      4507
