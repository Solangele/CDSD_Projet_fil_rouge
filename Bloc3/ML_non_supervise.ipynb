# %% [markdown]
# ## Imports

# %%
import os
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import librosa

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %% [markdown]
# ## Import et connexion à la base PostgreSQL Gold

# %%
load_dotenv(dotenv_path="../.env")

conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="datapulse_db",
    user=os.getenv("POSTGRES_USER"),
    password=os.getenv("POSTGRES_PASSWORD")
)

query = """
SELECT t.filename, t.minio_path, t.source_dataset, i.label_name as instrument
FROM audio_tracks t
JOIN instruments i ON t.instrument_id = i.id;
"""
df_gold = pd.read_sql(query, conn)
conn.close()
# Out:
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_42232\180464491.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold = pd.read_sql(query, conn)

# %%
def adapt_local_path(minio_path):
    """ 
    Résout et reconstruit le chemin d'accès physique local d'un fichier audio à partir de son identifiant de stockage distant (MinIO)

    Cette fonction utilitaire permet à la couche de modélisation (Orchestrateur Python) de localiser et charger en mémoire les signaux audio bruts. 
    Elle applique une règle de routage des dossiers selon l'origine du jeu de données (Philharmonia vs IRMAS)

    Argument : 
        minio_path (str) : le chemin logique de l'URI du fichier stocké dans le Data Lake de la couche Bronze (ex : "philharmonia/23.wav)
    
    Retourne :
        str : Le chemin d'accès système relatif vers le fichier local (ex : "../data/scrap/..."). 
    """
    if "philharmonia" in minio_path:
        return os.path.join("../data/scrap", minio_path)
    else:
        return os.path.join("../data", minio_path)

df_gold['chemin_local'] = df_gold['minio_path'].apply(adapt_local_path)
print(f"{len(df_gold)} pistes prêtes à être analysées via PostgreSQL Gold.")
# Out:
# 23262 pistes prêtes à être analysées via PostgreSQL Gold.

# %%
df_gold['chemin_local'] = df_gold['minio_path'].apply(adapt_local_path)

df_gold_clean = df_gold[
    df_gold['instrument'].notna() & 
    (df_gold['instrument'].str.lower() != 'unknown')
].reset_index(drop= True)

print(f"Pistes initiales dans PostgreSQL Gold : {len(df_gold)}")
print(f"Pistes nettoyées et viables pour l'IA : {len(df_gold_clean)} (727 'unknown' et 2 manquants supprimés).")
# Out:
# Pistes initiales dans PostgreSQL Gold : 23262
# Pistes nettoyées et viables pour l'IA : 22535 (727 'unknown' et 2 manquants supprimés).

# %% [markdown]
# ## Fonction d'extraction des Feaures Acoustiques

# %%
def extract_mfcc(chemin_fichier, n_mfcc=13):
    """
    Charge le signal temporel d'un fichier audio et calcule la moyenne de ses MFCCs (Mel Frequency Cepstral Coefficients (coefficients qui composent le cepstre de fréquence Mel (échelle psychoacoustique des sons))).

    Arguments : 
         chemin_fichier (str) : Chemin d'accès au fichier audio.
         n_mfcc (int) : Nombre de coefficients à extraire.

    Retourne :
        ndarray : Vecteur de caractéristiques (taille n_mfcc) ou None en cas d'erreur.
    """
    try:
        y, sr = librosa.load(chemin_fichier, duration=None, sr=None) 
        if len(y) == 0:
            return None

        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        return np.mean(mfccs.T, axis=0)
    except Exception as e:
        return None

# %% [markdown]
# ## Traitement global des caractéristiques sonores

# %%
audio_features_list = []
valid_indices = []

print("Extraction des signatures acoustiques (MFCC)...")
for idx, row in df_gold_clean.iterrows():
    features = extract_mfcc(row['chemin_local'])
    if features is not None:
        audio_features_list.append(features)
        valid_indices.append(idx)

df_analytics = df_gold_clean.iloc[valid_indices].reset_index(drop=True)
X_audio = np.array(audio_features_list)

print(f"Extraction terminée. Matrice d'analyse : {X_audio.shape}")
# Out:
# Extraction des signatures acoustiques (MFCC)...
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_42232\2006600829.py:13: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(chemin_fichier, duration=None, sr=None)
# c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Extraction terminée. Matrice d'analyse : (22533, 13)

# %% [markdown]
# ### Affichage des coefficients MFDD des 5 premières pistes audio

# %%
print(X_audio[:5, :])
# Out:
# [[-5.9334491e+02  4.9437874e+01  1.9304438e+01  7.3546329e+00
#    5.6513767e+00  6.3766742e+00  5.4290104e+00  3.3911316e+00
#    1.3163997e+00 -5.8591574e-01  1.2636805e-01  2.6572785e+00
#    3.6452954e+00]
#  [-6.4840753e+02  5.8463409e+01  2.1100006e+01  5.0588531e+00
#    3.8476796e+00  7.0988536e+00  8.6262980e+00  6.1055470e+00
#   -5.3304952e-01 -5.9669552e+00 -2.7812772e+00  5.9871144e+00
#    1.1251443e+01]
#  [-5.7310254e+02  4.6012943e+01  8.2211781e+00  1.1863085e+01
#    6.6395254e+00  5.6304326e+00 -1.7026304e+00 -6.3166803e-01
#   -4.1142014e-01 -3.8334405e+00  1.7577024e+00  2.5116453e-01
#    5.5022639e-01]
#  [-6.2751373e+02  6.2769157e+01  1.4222251e+01  8.2143602e+00
#    3.2663913e+00  5.8491821e+00  5.6674571e+00  1.3964224e+00
#   -3.0773211e-01 -1.6045929e+00  1.4679732e+00  2.9947791e+00
#    1.8354702e-03]
#  [-5.2134698e+02  3.1101255e+01  1.1709568e+01  5.9420266e+00
#    8.9097095e-01 -1.8892627e+00 -3.7675841e+00 -9.1748095e-01
#    3.7945826e+00  8.9743109e+00  9.8315887e+00  7.2799048e+00
#    3.5595024e+00]]

# %% [markdown]
# ## Séparation stricte Train/Test

# %%
X_train, X_test, df_train, df_test = train_test_split(
    X_audio, df_analytics, test_size=0.2, random_state=42, stratify=df_analytics['instrument']
)

# %% [markdown]
# ## Entraînment et réduction de dimension (sur le jeu Train uniquement)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


pca = PCA(n_components=2, random_state=42)
X_train_pca = pca.fit_transform(X_train_scaled)


kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
clusters_train = kmeans.fit_predict(X_train_scaled)


df_visu_train = pd.DataFrame(X_train_pca, columns=['Axe de timbre PCA 1', 'Axe de timbre PCA 2'])
df_visu_train['Cluster'] = clusters_train.astype(str)
df_visu_train['Instrument_Réel'] = df_train['instrument'].values

# %%
plt.figure(figsize=(11, 7))
sns.scatterplot(
    x='Axe de timbre PCA 1', 
    y='Axe de timbre PCA 2', 
    hue='Cluster', 
    data= df_visu_train, 
    palette='tab10',
    alpha= 0.6,
    edgecolor= None,
    s= 8 
)

plt.title("Segmentation non-supervisée (K-Means) des timbres audio après réduction PCA", fontsize=12, fontweight='bold')
plt.xlabel("Composante Principale 1 (Variations majeures du son)")
plt.ylabel("Composante Principale 2 (Variations secondaires)")
plt.legend(title="Groupes Acoustiques (Clusters)", loc='upper right')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyse de la pureté des clusters

# %%
def map_to_7_families(instrument_name):
    inst = str(instrument_name).lower().strip()
    if inst in ["organ"]:
        return "Orgues & Claviers Anciens"
    elif inst in ["banjo", "guitar", "mandolin", "electric_guitar", "acoustic_guitar"]:
        return "Famille des Cordes Pincées"
    elif inst in ["voice"]:
        return "Chant & Voix Humaines"
    elif inst in ["bassoon", "cello", "contrabassoon", "double bass", "viola", "violin"]:
        return "Famille des Cordes Frottées"
    elif inst in ["piano", "celesta"]:
        return "Pianos & Claviers Frappés"
    elif inst in ["percussion"]:
        return "Percussions"
    else:
        return "Instruments à Vent & Cuivres"
    

df_visu_train['Famille_Réelle'] = df_visu_train['Instrument_Réel'].apply(map_to_7_families)

crosstab_families = pd.crosstab(df_visu_train['Cluster'], df_visu_train['Famille_Réelle'])

plt.figure(figsize=(12, 6))
sns.heatmap(crosstab_families, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title("Répartition des Familles d'Instruments Réelles au sein des Clusters K-Means", fontsize=13, fontweight='bold', pad=20)
plt.xlabel("Familles Métiers Cibles", fontsize=11, labelpad=10)
plt.ylabel("Clusters K-Means", fontsize=11, labelpad=10)
plt.xticks(rotation=30, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation et projection sur le jeu de Test

# %%
X_test_pca = pca.transform(X_test_scaled)
predicted_test_clusters = kmeans.predict(X_test_scaled)

df_test_results = pd.DataFrame({
    'Instrument_Réel': df_test['instrument'].values,
    'Cluster_Prédit': predicted_test_clusters
})

print("=== Échantillon des prédictions de clusters sur le jeu de TEST ===")
display(df_test_results.head(10))
# Out:
# === Échantillon des prédictions de clusters sur le jeu de TEST ===
#    Instrument_Réel  Cluster_Prédit
# 0         clarinet               0
# 1            viola               2
# 2           violin               3
# 3         clarinet               0
# 4            piano               1
# 5      cor anglais               2
# 6    bass clarinet               0
# 7         clarinet               2
# 8  acoustic_guitar               0
# 9  acoustic_guitar               1

# %%
cluster_centroids = pd.DataFrame(
    kmeans.cluster_centers_, 
    columns=[f"MFCC {i}" for i in range(X_audio.shape[1])]
)
print("=== Profil acoustique moyen de chaque cluster (Centres) ===")
print(cluster_centroids.head())
# Out:
# === Profil acoustique moyen de chaque cluster (Centres) ===
#      MFCC 0    MFCC 1    MFCC 2    MFCC 3    MFCC 4    MFCC 5    MFCC 6  \
# 0 -0.200564  0.406469 -0.087182 -0.530364 -0.072933 -0.698051 -0.401591
# 1  1.423225  0.155369 -0.532631  1.092172 -0.666728  0.975530 -0.556277
# 2 -0.867158 -1.238482 -0.441061 -0.767004 -0.314348 -0.322559  0.317407
# 3 -0.371963  0.262177  1.044729  0.390335  1.048751  0.391328  0.915141
#
#      MFCC 7    MFCC 8    MFCC 9   MFCC 10   MFCC 11   MFCC 12
# 0 -0.759052 -0.525563 -0.659951 -0.486344 -0.565171 -0.383872
# 1  0.783809 -0.252783  0.339648 -0.135116  0.237520 -0.057666
# 2  0.397309  0.660724  0.898108  1.002676  0.953951  0.819021
# 3  0.066022  0.513413 -0.070935  0.043282 -0.164663 -0.038337
